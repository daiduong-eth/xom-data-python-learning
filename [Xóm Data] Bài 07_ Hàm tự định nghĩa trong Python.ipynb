# %% [markdown]
# # 🐍 SERIES TỰ HỌC PYTHON CÙNG XÓM
# ## BÀI 7: Hàm tự định nghĩa (User-Defined Functions)
#
# ### 🎯 Mục tiêu bài học:
# - Hiểu rõ cách tạo và sử dụng hàm do người dùng tự định nghĩa trong Python.
# - Biết cách truyền tham số, nhận giá trị trả về từ hàm.
#
# ✅ Ở các bài trước, chúng ta đã làm quen với các **Hàm dựng sẵn (Built-in Functions)** như `print()`, `type()`, `len()` và các **Method** của từng kiểu dữ liệu (list, string, dictionary...). Những hàm đó được Python cung cấp sẵn cho chúng ta dùng.
#
# ✅ Tuy nhiên, trong thực tế, có rất nhiều tình huống mà:
# - Bài toán mang tính đặc thù
# - Logic xử lý phức tạp
# - Cần tái sử dụng nhiều lần
#
# Lúc này, chúng ta cần tự viết ra những **Hàm tự định nghĩa (User-Defined Function)** để giải quyết bài toán của mình.
#
# 💡 Bắt đầu từ bài học này, Xóm sẽ đồng hành cùng bạn đi vào phần quan trọng bậc nhất trong lập trình: **tự viết hàm cho chính mình**.
#
# Cùng bắt đầu nhé! 👇

# %% [markdown]
# <!-- Tác giả: Xóm Data _ daiduong.eth -->
# ## **📚 F_02. User-Defined Function (Hàm tự định nghĩa trong Python)**
#
# Trong Python, **hàm (function)** là công cụ giúp bạn đóng gói một đoạn mã thực hiện một công việc cụ thể. Sau đó có thể **trả về một giá trị nào đó (return value)**.
#
# 👉 Trong phần F_02 này, chúng ta sẽ học cách **tự định nghĩa (define) các hàm của chính mình** — một kỹ năng quan trọng khi lập trình thực tế.
#
#
#
#
# ## **📌 Cú pháp cơ bản của hàm tự định nghĩa**
#
# Để định nghĩa một hàm trong Python, chúng ta sử dụng từ khóa `def`:
#
# ```python
# def ten_ham(tham_so_1, tham_so_2, ...):
#     # Khối lệnh xử lý bên trong hàm
#     # (có thể có hoặc không)
#     return gia_tri_tra_ve
# ```
#
# Giải thích:
#
# `def` là từ khóa bắt buộc khi định nghĩa hàm.
#
# `ten_ham` là tên do bạn tự đặt (theo quy tắc đặt tên biến).
#
# Trong ngoặc `()` là danh sách các tham số (có thể có hoặc không).
#
# `return` trả về giá trị ra bên ngoài hàm.

# %%
# Định nghĩa hàm cộng hai số
def cong_hai_so(a, b):
    tong = a + b
    return tong

# Gọi hàm
ket_qua = cong_hai_so(3, 5)
print(ket_qua)
# Out:
# 8

# %% [markdown]
# #### 📦 **Một vài đặc điểm của hàm tự định nghĩa trong Python**
#
# 1. ✅ Hàm **có thể có hoặc không có tham số truyền vào**.
# 2. ✅ Hàm **có thể có hoặc không có giá trị trả về (`return`)**.
# 3. ✅ Biến bên trong hàm có phạm vi riêng (**local scope**), chỉ tồn tại trong hàm.

# %% [markdown]
# #### **Ví Dụ**

# %%
### 1️⃣ Ví dụ hàm **không có tham số**

def xin_chao():
    print("Xin chào các bạn từ Xóm Data!")

# Gọi hàm
xin_chao()

###✅ Giải thích:
###    - Hàm xin_chao() không nhận bất kỳ tham số nào.
###    - Khi gọi hàm, chỉ cần ghi xin_chao() là đủ.
# Out:
# Xin chào các bạn từ Xóm Data!

# %%
### 2️⃣ Ví dụ hàm **có tham số**

def tinh_tong(a, b):
    return a + b

# Gọi hàm với đối số
ket_qua = tinh_tong(3, 5)
print("Tổng của 3 và 5 là:", ket_qua)

###✅ Giải thích:
###  - Hàm tinh_tong() nhận 2 tham số a và b.
###  - Khi gọi hàm, cần truyền vào đủ số lượng đối số tương ứng.
# Out:
# Tổng của 3 và 5 là: 8

# %%
### 3️⃣ Ví dụ hàm **không có giá trị trả về (`return`)**

def thong_bao():
    print("Hàm này chỉ in ra thông báo, không có return.")

# Gọi hàm
thong_bao()

### ✅ Giải thích:
### - Hàm thực hiện hành động in thông báo.
### - Không có câu lệnh `return`, nên hàm tự động trả về `None`.
# Out:
# Hàm này chỉ in ra thông báo, không có return.

# %%
### 4️⃣ Ví dụ hàm **có giá trị trả về (`return`)**

def tinh_hieu(a, b):
    return a - b

# Gọi hàm và nhận giá trị trả về
ket_qua = tinh_hieu(10, 3)
print("Hiệu của 10 và 3 là:", ket_qua)

### ✅ Giải thích:
### - Hàm có câu lệnh `return` để trả về kết quả.
### - Có thể gán kết quả trả về cho biến và sử dụng tiếp.
# Out:
# Hiệu của 10 và 3 là: 7

# %%
### 5️⃣ Ví dụ hàm **không có tham số nhưng có giá trị trả về (`return`)**

def get_xom_data_name():
    return "Xóm Data"

# Gọi hàm và nhận giá trị trả về
ten_group = get_xom_data_name()
print("Tên nhóm là:", ten_group)

### ✅ Giải thích:
### - Hàm không cần tham số đầu vào.
### - Hàm vẫn trả về giá trị bằng câu lệnh `return`.
# Out:
# Tên nhóm là: Xóm Data

# %%
### 6️⃣ Ví dụ về **phạm vi biến trong hàm (Local Scope)**

def demo_scope():
    x = 10
    print("Giá trị x trong hàm:", x)

# Gọi hàm
demo_scope()

print(x)  # Lỗi: NameError vì x không tồn tại bên ngoài hàm

### ✅ Giải thích:
### - Biến `x` chỉ tồn tại trong phạm vi của hàm (`local scope`).
### - Bên ngoài hàm không thể truy cập được biến `x`.
# Out:
# Giá trị x trong hàm: 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3834376564> in <cell line: 0>()
#       8 demo_scope()
#       9
# ---> 10 print(x)  # Lỗi: NameError vì x không tồn tại bên ngoài hàm
#      11
#      12 ### ✅ Giải thích:
#
# NameError: name 'x' is not defined

# %%
### 7️⃣ Ví dụ về **biến toàn cục (Global Scope)**

x = 22  # Biến toàn cục

def demo_global_1():
    x = 10
    print("Giá trị x toàn cục bên trong hàm:", x)

def demo_global_2():
    print("Giá trị x toàn cục bên trong hàm:", x)

# Gọi hàm
demo_global_1()
demo_global_2()
print("Giá trị x toàn cục bên ngoài hàm:", x)

### ✅ Giải thích:
### - Biến `x` được khai báo bên ngoài tất cả các hàm → global scope.
### - Các hàm có thể đọc được giá trị global nếu không ghi đè.
# Out:
# Giá trị x toàn cục bên trong hàm: 10
# Giá trị x toàn cục bên trong hàm: 22
# Giá trị x toàn cục bên ngoài hàm: 22

# %% [markdown]
# ## 🧠 BÀI TẬP THỰC HÀNH
#
# Để làm bài các bạn hãy viết vào các cell code ở mỗi bài nhé! 👇

# %%
# Bài 1: Viết hàm `chao_mung()` để in ra câu: "Chào mừng bạn đến với Xóm Data"

# %%
# Bài 2: Viết hàm `tinh_binh_phuong(n)` nhận vào 1 số và trả về bình phương của số đó.

# %%
# Bài 3: Viết hàm `tong_nhan_doi(a, b)` nhận vào 2 số, tính tổng của chúng, sau đó nhân đôi kết quả và trả về. Ví dụ 2, 3 đưa vào thì return ra giá trị 10.

# %%
# Bài 4: Viết hàm `kiem_tra_chan_le(n)` nhận vào 1 số nguyên. Nếu là số chẵn in "Số chẵn", nếu là số lẻ in "Số lẻ".

# %%
# Bài 5: Viết hàm `tinh_giai_thua(n)` nhận vào 1 số nguyên dương n và trả về giai thừa của n (n!).

# %%
# Bài 6: Viết hàm `dem_so_nguyen_to(n)` đếm có bao nhiêu số nguyên tố từ 2 đến n.

# %%
# Bài 7: Viết hàm `kiem_tra_palindrome(s)` kiểm tra 1 chuỗi s có phải là palindrome (đọc xuôi hay ngược đều giống nhau) hay không.

# %%
# Bài 8: Viết hàm `tinh_tong_so_le(lst)` nhận vào 1 list các số, trả về tổng của các số lẻ trong list đó.

# %%
# Bài 9: Viết hàm `dem_tan_suat_ky_tu(s)` nhận vào một chuỗi s, trả về dictionary chứa số lần xuất hiện của từng ký tự trong chuỗi.

# %%
# Bài 10: Viết hàm `giao_cua_2_list(list1, list2)` nhận vào 2 list, trả về list chứa các phần tử chung của cả 2 list (không trùng lặp).
