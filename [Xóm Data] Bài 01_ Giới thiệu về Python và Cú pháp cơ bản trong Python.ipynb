# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
#
# # 🐍 Giới thiệu về Python
#
# **Python** là một ngôn ngữ lập trình thông dịch bậc cao, được tạo ra vào năm 1990 bởi cha đẻ **Guido van Rossum**. Python hiện nay là một trong những ngôn ngữ tuyệt vời cho những bạn lần đầu tiếp xúc với lập trình và **phân tích dữ liệu**.
#
# ## 📌 Vì sao Python lại phổ biến trong Data Analytics?
#
# - 🔧 **Dễ học, dễ đọc**: Python có cú pháp gần với ngôn ngữ tự nhiên, rất phù hợp với người mới bắt đầu.
# - 📊 **Hệ sinh thái thư viện mạnh mẽ**: Bao gồm các thư viện như:
#   - `pandas`: thao tác và xử lý dữ liệu dạng bảng (DataFrame)
#   - `numpy`: tính toán khoa học, xử lý mảng số liệu
#   - `matplotlib`, `seaborn`: trực quan hóa dữ liệu
#   - `scikit-learn`: mô hình hóa và máy học
# - ⏱️ **Tăng tốc công việc**: Giúp tự động hóa các tác vụ lặp đi lặp lại, phân tích dữ liệu nhanh chóng và linh hoạt.
# - 🤝 **Tích hợp tốt với các công cụ khác**: Python dễ dàng tích hợp với SQL, Excel, Google Sheets, APIs, và cả các nền tảng như BigQuery, Spark.
#
# ## 📈 Tự học Python cùng Xóm Data
#
# Với sự cần thiết của Python trong hành trình làm nghề Data, hôm nay hãy cùng học Python từ đầu với chúng mình nhé!!
#
# ---
#
# ## 🔗 Tài liệu tham khảo
#
# - [W3Schools](https://www.w3schools.com/python/)
# - [Python Documentation](https://docs.python.org/)
#
# ---
#
# ## 📚 Tham gia cộng đồng Xóm Data
#
# - 🌐 Website: [https://www.xomdata.com/](https://www.xomdata.com/)
# - 💬 Group Facebook: [Xóm Data Community](https://www.facebook.com/groups/xomdata)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 🐍 SERIES TỰ HỌC PYTHON CÙNG XÓM
# ## Bài 01: Giới thiệu về Python và Cú pháp cơ bản trong Python.ipynb

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# ## **🧾 A. Python Syntax (Cú pháp Python cơ bản)**
#
# **Cú pháp (syntax)** trong Python rất rõ ràng và dễ đọc, các từ khóa đều là các từ Tiếng Anh thông dụng, đây là một trong những lý do chính khiến Python trở thành một ngôn ngữ phổ biến.

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# ### **I. Line Structure**
#
# **Line Structure** (cấu trúc dòng) trong Python mô tả cách các dòng mã được viết và hiểu bởi trình thông dịch. Việc nắm rõ cấu trúc dòng giúp viết code đúng cú pháp và dễ bảo trì.

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ✅ 1. Mỗi dòng là một câu lệnh
#
# Trong Python, mỗi dòng thường tương ứng với một lệnh riêng biệt.

# %%
x = 22
y = 10
print(x + y)
# Out:
# 32

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ✅ 2. Nhiều lệnh trên một dòng (Multiple statements)
#
# Dùng dấu `;` để phân tách các lệnh nếu muốn viết chúng trên cùng một dòng.

# %%
a = 22; b = 10; print(a + b)
# Out:
# 32

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ✅ 3. Xuống dòng (Line continuation)
#
# **a. Ngầm định (Implicit)**:
# Nếu lệnh nằm trong dấu ngoặc `()`, `[]`, `{}`, bạn có thể xuống dòng mà không cần ký hiệu đặc biệt.

# %%
numbers = [
    2, 2, 1,
    0, 9,
    9
]
print(numbers)
# Out:
# [2, 2, 1, 0, 9, 9]

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# **b. Tường minh (Explicit)**:
# Dùng dấu `\` để báo hiệu rằng dòng tiếp theo là phần tiếp của dòng hiện tại.

# %%
print('Xin chào các bạn,\
 mình là Xóm Data!')
# Out:
# Xin chào các bạn, mình là Xóm Data!

# %%
total = 2 + 2 + 1 + \
        0 + 9 + 9
print(total)
# Out:
# 23

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# ### **II. Python Indentation**
# **Indentation** (thụt dòng) là **cách Python xác định khối lệnh (code block)**. Bạn có thể hiểu đơn giản khối lệnh là một tập hợp các lệnh tuần tự được gói vào 1 khối. Không giống như nhiều ngôn ngữ lập trình phải dùng dùng dấu `{}`, Python sử dụng khoảng trắng đầu dòng để phân biệt các khối lệnh.
#
# Việc thụt dòng **không đúng** sẽ khiến chương trình báo lỗi cú pháp.

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ✅ Ví dụ đúng về thụt dòng
# Dưới đây là đoạn code đúng cú pháp với thụt dòng sau lệnh `if`.

# %%
if 22 > 10:
    print("22 lớn hơn 10")
    print("Đây là 1 khối lệnh !!")
# Out:
# 22 lớn hơn 10
# Đây là 1 khối lệnh !!

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ❌ Ví dụ sai: Không thụt dòng
#
# Nếu bạn không thụt dòng sau lệnh điều kiện, Python sẽ báo lỗi `IndentationError`.

# %%
if 22 > 10:
print("22 lớn hơn 10")
# Out:
#   File "<ipython-input-8-e43d3b996a1b>", line 2
#     print("22 lớn hơn 10")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### 🔸 Bao nhiêu khoảng trắng?
#
# Bạn có thể dùng **bao nhiêu khoảng trắng tùy ý**, nhưng trong **cùng một khối lệnh**, phải **dùng thống nhất**.

# %%
if True:
    x = 22
    y = 10
    print(x + y)

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ⚠️ Lỗi do không thống nhất thụt dòng
#
# Ví dụ dưới đây dùng **2 khoảng trắng cho dòng đầu, 4 cho dòng tiếp theo** → sẽ gây lỗi.

# %%
if True:
  x = 22
  y = 10
    print(x + y)

# %% [markdown]
# ---

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# ## **🧾 B. Python Comments (Chú thích trong Python)**
#
# **Comment** là phần chú thích trong mã nguồn, giúp giải thích hoặc ghi chú lại logic của chương trình. Trình thông dịch Python **sẽ bỏ qua phần comment khi chạy code**.

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# ### **I. Comment một dòng (Single-line)**
#
# Dùng dấu `#` để viết comment trên một dòng bất kỳ. Python sẽ bỏ qua toàn bộ nội dung phía sau dấu `#` trên dòng đó.

# %%
# Đây là một comment
print("Hello, Xóm Data!")  # Đây cũng là một comment sau lệnh

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# ### **II. Comment nhiều dòng (Multi-line)**
#
# Python có cách cách phổ biến để viết comment nhiều dòng như sau:

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ➤ Cách 1: Dùng nhiều dấu `#` cho từng dòng

# %%
# Đây là dòng đầu tiên của comment
# Đây là dòng thứ hai
# Đây là dòng thứ ba
print("Chạy xong comment nhiều dòng")

# %% [markdown]
# <!-- Tác giả: Xóm Data _ Nhan Như Ngọc -->
# #### ➤ Cách 2: Dùng chuỗi nhiều dòng (triple quotes)
#
# Dùng `'''` hoặc `"""` để bao quanh đoạn văn bản. Nếu không gán cho biến nào, Python sẽ bỏ qua — nên có thể dùng như comment.

# %%
"""
Đây là comment nhiều dòng
Viết bằng chuỗi triple-quote
Không ảnh hưởng đến chương trình
"""
print("Chạy xong triple quote comment")
