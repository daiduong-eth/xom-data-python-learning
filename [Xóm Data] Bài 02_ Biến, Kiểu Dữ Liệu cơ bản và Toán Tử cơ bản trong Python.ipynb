# %% [markdown]
# # 🐍 SERIES TỰ HỌC PYTHON CÙNG XÓM
# ## BÀI 2: Biến, Kiểu Dữ Liệu và Toán Tử trong Python
#
# ### 🎯 Mục tiêu bài học:
# - Tìm hiểu Biến trong Python.
# - Làm quen với các kiểu Dữ Liệu Cơ Bản trong Python: `int`, `float`, `str`, `bool`, `NoneType`
# - Hiểu và sử dụng được các loại toán tử: số học, so sánh, logic, gán
# - Ứng dụng vào một số ví dụ thực tế nhỏ
#
# Cùng bắt đầu nhé! 👇

# %% [markdown]
# <!-- Tác giả: Xóm Data _ daiduong.eth -->
# ## **🧾 C. Python Variables (Biến trong Python)**
#
# **Biến (variable)** trong Python là **tên gọi** mà bạn đặt để **lưu trữ một giá trị nào đó** trong bộ nhớ.
#
# Nói đơn giản:
# - Nếu dữ liệu là "thông tin", thì biến là "cái nhãn dán" giúp bạn gọi tên và sử dụng lại thông tin đó sau này.
# - Mỗi biến có một **tên** (do bạn đặt) và một **giá trị** (bạn gán vào nó).

# %%
### Ví dụ:
name = "Xóm Data"     # biến 'name' chứa chuỗi "Xóm Data"
age = 2025            # biến 'age' chứa số nguyên 2025

print(name)
print(age)
# Out:
# Xóm Data
# 2025

# %% [markdown]
# <!-- Tác giả: Xóm Data _ daiduong.eth -->
# #### ✅ 1. Cách đặt tên biến và những lưu ý
#
# Khi khai báo một biến trong Python, bạn được **tự đặt tên cho biến**. Nhưng cần tuân thủ một số quy tắc quan trọng để tránh lỗi và giúp code dễ đọc.
#
# **Quy tắc đặt tên biến:**
#
# 1. **Chỉ chứa**: chữ cái (a–z, A–Z), số (0–9), và dấu gạch dưới `_`
# 2. **Không bắt đầu** bằng số
# 3. **Không trùng** với từ khóa của Python (như `if`, `for`, `class`, `True`, `None`, ...)
# 4. Python **phân biệt chữ hoa và chữ thường**
#    → `score`, `Score`, `SCORE` là 3 biến khác nhau
# 5. Nên đặt tên biến **có ý nghĩa**, không nên đặt kiểu `a`, `b`, `x1`,...

# %% [markdown]
# #### ✅ 2. Ví dụ

# %%
# Hợp lệ
user_name = "Xóm viên"
age = 22
AGE = 10

print(user_name)
print(age)
print(AGE)
# Out:
# Xóm viên
# 22
# 10

# %% [markdown]
# <!-- Tác giả: Xóm Data _ daiduong.eth -->
# ## **🧾 D_01. Python Data Types (Kiểu Dữ Liệu trong Python)**
#
# Trong Python, **mọi giá trị** đều thuộc **một kiểu dữ liệu** nào đó.
#
# Việc hiểu và sử dụng đúng kiểu dữ liệu sẽ giúp bạn:
# - Tránh lỗi khi xử lý dữ liệu (nhất là khi phân tích số liệu)
# - Biết được mình có thể làm gì với giá trị đó (cộng, nối chuỗi, kiểm tra điều kiện, v.v.)

# %% [markdown]
# #### ✅ 1. Một số kiểu dữ liệu cơ bản mà bạn cần biết:
#
# | Kiểu dữ liệu     | Mô tả                            | Ví dụ giá trị                  |
# |------------------|----------------------------------|--------------------------------|
# | `int`            | Số nguyên                        | `1`, `100`, `-20`              |
# | `float`          | Số thực (thập phân)              | `3.14`, `0.01`, `-7.5`         |
# | `str` (string)   | Chuỗi ký tự                      | `"Hello"`, `'Xóm Data'`       |
# | `bool`           | Boolean – giá trị đúng/sai       | `True`, `False`               |
# | `NoneType`       | Đại diện cho "không có gì cả"   | `None`                         |

# %% [markdown]
# #### ✅ 2. Kiểu `int` – Số nguyên
#
# Dùng để biểu diễn các số nguyên như: `-1`, `0`, `100`, `2025`.

# %%
x = 10
print(x)
print("Kiểu dữ liệu:", type(x))
# Out:
# 10
# Kiểu dữ liệu: <class 'int'>

# %% [markdown]
# #### ✅ 3. Kiểu `float` – Số thực
#
# Dùng để biểu diễn số có phần thập phân như: `3.14`, `-0.5`, `10.0`.

# %%
pi = 3.14
print(pi)
print("Kiểu dữ liệu:", type(pi))
# Out:
# 3.14
# Kiểu dữ liệu: <class 'float'>

# %% [markdown]
# #### ✅ 4. Kiểu `str` – Chuỗi ký tự
#
# Chuỗi là một dãy ký tự được đặt trong dấu `" "` hoặc `' '`.

# %%
greeting = "Chào mừng bạn đến với Xóm Data!"
print(greeting)
print("Kiểu dữ liệu:", type(greeting))
# Out:
# Chào mừng bạn đến với Xóm Data!
# Kiểu dữ liệu: <class 'str'>

# %% [markdown]
# #### ✅ 5. Kiểu `bool` – Đúng hoặc Sai
#
# Chỉ có hai giá trị: `True` hoặc `False`.

# %%
is_data_fun = True
print(is_data_fun)
print("Kiểu dữ liệu:", type(is_data_fun))
# Out:
# True
# Kiểu dữ liệu: <class 'bool'>

# %% [markdown]
# #### ✅ 6. Kiểu `NoneType` – Không có giá trị
#
# `None` biểu thị một giá trị rỗng, chưa xác định.

# %%
value = None
print(value)
print("Kiểu dữ liệu:", type(value))
# Out:
# None
# Kiểu dữ liệu: <class 'NoneType'>

# %% [markdown]
# <!-- Tác giả: Xóm Data _ daiduong.eth -->
# ## **🧾 E_01. Python Operators (Toán Tử trong Python)**
#
# **Toán tử (operators)** là các ký hiệu dùng để thực hiện các phép tính hoặc so sánh giữa các giá trị.
#
# Trong Python, chúng ta thường dùng các loại toán tử sau:
# - Toán tử số học
# - Toán tử so sánh
# - Toán tử logic
# - Toán tử gán

# %% [markdown]
# #### ✅ 1. Toán Tử Số Học
#
# Dùng để thực hiện các phép tính cơ bản như cộng, trừ, nhân, chia...
#
# | Toán tử | Ý nghĩa        | Ví dụ        |
# |--------|----------------|--------------|
# | `+`    | Cộng           | `a + b`      |
# | `-`    | Trừ            | `a - b`      |
# | `*`    | Nhân           | `a * b`      |
# | `/`    | Chia           | `a / b`      |
# | `//`   | Chia lấy nguyên | `a // b`     |
# | `%`    | Chia lấy dư    | `a % b`      |
# | `**`   | Lũy thừa       | `a ** b`     |

# %%
a = 7
b = 3

print("Cộng:", a + b)
print("Trừ:", a - b)
print("Nhân:", a * b)
print("Chia:", a / b)
print("Chia lấy phần nguyên:", a // b)
print("Chia lấy dư:", a % b)
print("Lũy thừa:", a ** b)
# Out:
# Cộng: 10
# Trừ: 4
# Nhân: 21
# Chia: 2.3333333333333335
# Chia lấy phần nguyên: 2
# Chia lấy dư: 1
# Lũy thừa: 343

# %% [markdown]
# #### ✅ 2. Toán Tử So Sánh
# Dùng để so sánh hai giá trị, kết quả trả về là `True` hoặc `False`.
#
# | Toán tử | Ý nghĩa              |
# |--------|-----------------------|
# | `==`   | bằng nhau             |
# | `!=`   | không bằng nhau       |
# | `>`    | lớn hơn               |
# | `<`    | nhỏ hơn               |
# | `>=`   | lớn hơn hoặc bằng     |
# | `<=`   | nhỏ hơn hoặc bằng     |

# %%
x = 22
y = 10

print(x == y)   # bằng
print(x != y)   # không bằng
print(x > y)    # lớn hơn
print(x < y)    # nhỏ hơn
print(x >= y)   # lớn hơn hoặc bằng
print(x <= y)   # nhỏ hơn hoặc bằng
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# #### ✅ 3. Toán Tử Logic
# Dùng để kết hợp các điều kiện (boolean).
#
# | Toán tử | Ý nghĩa                     |
# |--------|------------------------------|
# | `and`  | cả hai điều kiện đều đúng   |
# | `or`   | một trong hai đúng là được |
# | `not`  | phủ định điều kiện          |

# %%
a = True
b = False

print(a and b)  # cả hai phải đúng
print(a or b)   # một trong hai đúng là được
print(not a)    # phủ định
# Out:
# False
# True
# False

# %% [markdown]
# #### ✅ 4. Toán Tử Gán
# Dùng để gán giá trị cho biến. Có thể kết hợp với các toán tử khác.
#
# | Toán tử | Ví dụ      | Ý nghĩa                  |
# |--------|------------|---------------------------|
# | `=`    | `x = 5`    | gán giá trị 5 cho x       |
# | `+=`   | `x += 1`   | x = x + 1                  |
# | `-=`   | `x -= 1`   | x = x - 1                  |
# | `*=`   | `x *= 2`   | x = x * 2                  |
# | `/=`   | `x /= 2`   | x = x / 2                  |

# %%
# Gán giá trị ban đầu
x = 123
print("Ban đầu x =", x)

# += : cộng rồi gán
x += 5    # tương đương x = x + 5
print("Sau x += 5:", x)

# -= : trừ rồi gán
x -= 3    # tương đương x = x - 3
print("Sau x -= 3:", x)

# *= : nhân rồi gán
x *= 2    # tương đương x = x * 2
print("Sau x *= 2:", x)

# /= : chia rồi gán
x /= 4    # tương đương x = x / 4
print("Sau x /= 4:", x)

# //= : chia lấy nguyên rồi gán
x //= 2   # tương đương x = x // 2
print("Sau x //= 2:", x)

# %= : chia lấy dư rồi gán
x %= 4    # tương đương x = x % 4
print("Sau x %= 3:", x)

# **= : lũy thừa rồi gán
x **= 2   # tương đương x = x ** 2
print("Sau x **= 2:", x)
# Out:
# Ban đầu x = 123
# Sau x += 5: 128
# Sau x -= 3: 125
# Sau x *= 2: 250
# Sau x /= 4: 62.5
# Sau x //= 2: 31.0
# Sau x %= 3: 3.0
# Sau x **= 2: 9.0

# %% [markdown]
# ## 🧠 BÀI TẬP THỰC HÀNH
#
# Hãy mở một ô code mới bên dưới mỗi bài và tự mình giải nhé! 👇

# %% [markdown]
# #### ✅ Bài 1: Khai báo biến cá nhân
# Khai báo các biến sau và in ra màn hình:
# - Họ tên của bạn (kiểu `str`)
# - Tuổi của bạn (kiểu `int`)
# - Bạn có phải là học viên Xóm Data không? (kiểu `bool`)

# %% [markdown]
# #### ✅ Bài 2: Kiểm tra kiểu dữ liệu
# Tạo một số biến với giá trị tùy chọn, sau đó dùng `type()` để in ra kiểu dữ liệu của từng biến:
# - Một số nguyên
# - Một số thực
# - Một chuỗi
# - Một biến chưa có giá trị (`None`)

# %% [markdown]
# #### ✅ Bài 3: Tính tuổi trung bình
# Cho ba người có tuổi là: 23, 25 và 30.
# - Tạo biến lưu trữ từng độ tuổi
# - Tính và in ra tuổi trung bình

# %% [markdown]
# #### ✅ Bài 4: Ghép chuỗi
# Tạo 2 biến:
# ```python
# first_name = "Xóm"
# last_name = "Data"
# ```
# → In ra dòng: Xin chào, tôi là Xóm Data (gợi ý: dùng phép + để nối chuỗi)

# %% [markdown]
# #### ✅ Bài 5: So sánh tuổi
# Cho tuổi bạn là 22 và tuổi bạn A là 25.
# - Tạo 2 biến `my_age` và `friend_age`
# - In ra kết quả của các biểu thức so sánh: `==`, `>`, `<`

# %% [markdown]
# #### ✅ Bài 6: Toán tử logic
# Cho:
# ```python
# has_laptop = True
# has_internet = False
# ```
# - Kiểm tra xem bạn có đủ điều kiện học online không (dùng `and`)
# - Kiểm tra xem bạn có thể học ít nhất một phần (dùng `or`)

# %% [markdown]
# #### ✅ Bài 7: Cập nhật điểm số
# Giả sử bạn có biến `score = 70`
# - Cộng thêm 10 điểm
# - Nhân đôi điểm
# - Sau đó chia cho 4
# In ra kết quả cuối cùng sau mỗi bước (gợi ý: dùng các toán tử gán `+=`, `*=`, `/=`)
